# %%
from selenium import webdriver
from PIL import Image
import os
from os import path
import time
import random
import pandas as pd
import requests
import json
import numpy as np

# %%
import code.visualizations as viz
import code.data_preparation as dprep

# %% [markdown]
# ## Load API keys

# %%
def get_api_keys():
    '''Returns the keys for calls to 3 apis. The key is stored in secret file on local computer'''
    with open('C:/Users/james/.secret/patronOmdb.txt', 'r') as f:
        omdb_key = f.read()

    with open('C:/Users/james/.secret/imdbApi.txt', 'r') as g:
        imdb_key = g.read()
        
    return (omdb_key, imdb_key, tmdb_key)

# %%
api_keys = get_api_keys()
omdb_key = api_keys[0]
imdb_key = api_keys[1]
tmdb_key = api_keys[2]

# %% [markdown]
# ## Scraping functions

# %% [markdown]
# ### Scrape financial details from the numbers website and make a list of lists

# %%
def the_numbers_scraping():
    '''Srapes the Numbers webite with Selenium, returns a list of lists, each containing financial details for a movie'''
    chromedriver = 'C:/Users/james/AppData/Local/Google/Chrome/chromedriver.exe'
    os.environ["webdriver.chrome.driver"] = chromedriver
    driver = webdriver.Chrome(chromedriver)
    financials_list = []
    #scroll through 62 pages
    for r in range(62):
        time.sleep(random.uniform(2, 4))
        if r == 0:
            url = 'https://www.the-numbers.com/movie/budgets/all'
        else:
            url = 'https://www.the-numbers.com/movie/budgets/all/' + str(r) + '01'
        driver.get(url)  
        mytable = driver.find_element_by_css_selector('table')
        for row in mytable.find_elements_by_css_selector('tr'):
            row_list=[]
            cn=0
            for cell in row.find_elements_by_tag_name('td'):
                if cn != 0:  
                    row_list.append(cell.text)
                cn+=1
            if row_list:
                financials_list.append(row_list)
    return financials_list

# %%
financials_list = the_numbers_scraping()
financials_list[:3]
# Out:
# [['Apr 23, 2019',
#   'Avengers: Endgame',
#   ' $400,000,000',
#   ' $858,373,000',
#   ' $2,797,800,564'],
#  ['May 20, 2011',
#   'Pirates of the Caribbean: On Stranger Tides',
#   ' $379,000,000',
#   ' $241,071,802',
#   ' $1,045,713,802'],
#  ['Apr 22, 2015',
#   'Avengers: Age of Ultron',
#   ' $365,000,000',
#   ' $459,005,868',
#   ' $1,395,316,979']]

# %%
with open("data/financials_list.json", "w") as ffp:
        json.dump(financials_list, ffp)

# %% [markdown]
# ### Make numbers_df, from the list of lists. Filter out corrupt/anomalous rows by rejecting movies with no worldwide takings and movies with budget < 1m dollars and only include movies with presence in the US

# %%
def construct_prepare_numbers_df(financials_list):
    '''Takes in the Numbers list of lists, returns a dataframe and formats data'''
    numbers_df = pd.DataFrame(financials_list)
    numbers_df.columns=['release_date', 'title', 'budget_$', 'domestic_box_office_$', 'worldwide_box_office_$']

    # strip '$' ' '  ','  from values that need to be floats
    numbers_df= numbers_df.applymap(lambda x: x.strip())
    numbers_df= numbers_df.applymap(lambda x: x[1:].replace(',', '') if  x[0] == "$" else x)
    
    # create colums to break up the release date
    numbers_df.insert(1, "release_year", "")
    numbers_df.insert(2, "release_month", "")
    numbers_df.insert(3, "release_day", "")
    
    #split up the date into d/m/y
    no_date_list = []
    for index, row in numbers_df.iterrows():
        try:
            date_list=row['release_date'].replace(',', '').split()
            row['release_year'] = date_list[2]
            row['release_month'] = date_list[0]
            row['release_day'] = date_list[1]
        except:
            no_date_list.append([row['title'], date_list])
            
    numbers_df = numbers_df[['title', 'release_year', 'release_month', 'release_day', 'budget_$', 'domestic_box_office_$', 'worldwide_box_office_$']]
    
    # insert dummy date if not present to allow int coversion
    for index, row in numbers_df.iterrows():
        if row['release_year'] == '':
            row['release_year'] = '0'
        
    # make columns numeric
    numbers_df[['release_year', 'budget_$', 'domestic_box_office_$', 'worldwide_box_office_$']] = numbers_df[['release_year', 'budget_$', 'domestic_box_office_$', 'worldwide_box_office_$']].astype('int64')
    
    #filter out any movies with less than $1m budget
    numbers_df = numbers_df[numbers_df['budget_$'] >1000000]
    
    # filter out any films where worldwide figures suggest unusable film, and where domestic 
    # takings suggest it was only a hit outside the US
    
    numbers_df = numbers_df[numbers_df['domestic_box_office_$'] > 0]
    numbers_df = numbers_df[numbers_df['worldwide_box_office_$'] > 0]
        
    return numbers_df

# %%
numbers_df = construct_prepare_numbers_df(financials_list)

# %%
numbers_df.to_csv('data/numbers_df.csv', index=False)

# %% [markdown]
# ### Make financials_df, which is a copy of numbers_df but with profit/loss columns added and filtered to include only movies released in last 15 years. Also adds empty column added to hold imdb_code

# %%
def make_fin_15(numbers_df):
    '''Takes in the Numbers dataframe and filters to only include movies from last 15 years and add profit, imdb_code columns'''
    financials_15_df = numbers_df.copy()
    
    # make imdb_code column that will be primary key and used to join to the attributes df later
    financials_15_df.insert(0, "imdb_code", "No_code")
       
    # make profit/loss columns - gross and return on investment and column of domestic share of takings
    financials_15_df['profit_loss_$'] = financials_15_df['worldwide_box_office_$'] - financials_15_df['budget_$']
    financials_15_df['return_pct'] = (100 / financials_15_df['budget_$']) * financials_15_df['profit_loss_$']
    financials_15_df['domestic_%'] = 100 * (financials_15_df['domestic_box_office_$'] / financials_15_df['worldwide_box_office_$'])
    
    # filter for only last 15 years
    financials_15_df = financials_15_df[financials_15_df['release_year'] >= 2007]
    
    return financials_15_df

# %%
financials_15_df = make_fin_15(numbers_df)

# %% [markdown]
# ## API functions

# %% [markdown]
# ### Use omdb api to get attributes for movies in numbers_df. The response is stored in global dictionary omdb_attrs that will be used to create the attributes_df dataframe. It also updates the imdb_code column in financials_15_df. It also makes a list of failed calls, due to ambiguous title

# %%
omdb_attrs = {}
dud_url=[]
retrieve_error=[]

def on_success(financials_15_df, movie_data, movie):
    imdb_id = movie_data['imdbID'] 
    financials_15_df['imdb_code'][financials_15_df.title == movie] = imdb_id
    keys = ['Actors', 'Director', 'Genre', 'Plot', 'Rated', 'Ratings', 'Runtime', 'Writer', 'Title', 'imdbRating', 'imdbVotes']
    omdb_attrs[imdb_id] = {x:movie_data[x] for x in keys}

def url_maker(year, title, omdb_key):
    url = 'http://www.omdbapi.com/?t=' + title + '&y=' + year + '&apikey=' + omdb_key
    return url


def get_page(url):
    response=requests.get(url)
    movie_data = json.loads(response.content.decode('utf-8')) 
    return movie_data

def make_omdb_dict(financials_15_df, omdb_key):
    '''The engine of the OMDB API calls. It iterates through each movie in financials_15_df and retrieves its metadata from 
    omdb. It returns a dictionary of dictionaries containing metadata for each film. It also adds the imdb_code to 
    financials_15_df and constructs a list of movies where the API call fails due to an ambiguous title
    The important films from that list are manually stored in the manual_list variable below, and their imdb_codes manually obtained from 
    imdb website. They are then fed into the following functions to perform the same tasks with the ambiguously titled movies'''
    for index, row in financials_15_df.iterrows():
        movie = row['title']
        title = movie.replace(',', '%2C').replace (' ', '+').replace (':', '%3A')
        year = str(row['release_year'])
        url = url_maker(year, title, omdb_key)
        try:
            movie_data = get_page(url)
            if "Error" in movie_data: 
                #try previous release year
                prev_year = (str(int(year) -1))
                url = url_maker(prev_year, title, omdb_key)
                movie_data = get_page(url)  
                if "Error" in movie_data:
                    film_error = movie + " - " + movie_data_t['Error'] + "\n"
                    retrieve_error.append(prev_film_error)
                else:
                    on_success(financials_15_df, movie_data, movie)
            else:
                on_success(financials_15_df, movie_data, movie)  
        except:
            dud_url.append(movie)

    return (omdb_attrs, financials_15_df)


update_dud_url=[]
update_retrieve_error=[]

# %%
(omdb_attrs, financials_15_df) = make_omdb_dict(financials_15_df, omdb_key)
# Out:
# <ipython-input-14-1388f0215367>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financials_15_df['imdb_code'][financials_15_df.title == movie] = imdb_id

# %%
omdb_attrs
# Out:
# {'tt4154796': {'Actors': 'Robert Downey Jr., Chris Evans, Mark Ruffalo',
#   'Director': 'Anthony Russo, Joe Russo',
#   'Genre': 'Action, Adventure, Drama',
#   'Plot': "After the devastating events of Avengers: Infinity War (2018), the universe is in ruins. With the help of remaining allies, the Avengers assemble once more in order to reverse Thanos' actions and restore balance to the universe.",
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.4/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '94%'},
#    {'Source': 'Metacritic', 'Value': '78/100'}],
#   'Runtime': '181 min',
#   'Writer': 'Christopher Markus, Stephen McFeely, Stan Lee',
#   'Title': 'Avengers: Endgame',
#   'imdbRating': '8.4',
#   'imdbVotes': '937,294'},
#  'tt1298650': {'Actors': 'Johnny Depp, Penélope Cruz, Ian McShane',
#   'Director': 'Rob Marshall',
#   'Genre': 'Action, Adventure, Fantasy',
#   'Plot': 'Jack Sparrow and Barbossa embark on a quest to find the elusive fountain of youth, only to discover that Blackbeard and his daughter are after it too.',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.6/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '33%'},
#    {'Source': 'Metacritic', 'Value': '45/100'}],
#   'Runtime': '136 min',
#   'Writer': 'Ted Elliott, Terry Rossio, Stuart Beattie',
#   'Title': 'Pirates of the Caribbean: On Stranger Tides',
#   'imdbRating': '6.6',
#   'imdbVotes': '497,245'},
#  'tt2395427': {'Actors': 'Robert Downey Jr., Chris Evans, Mark Ruffalo',
#   'Director': 'Joss Whedon',
#   'Genre': 'Action, Adventure, Sci-Fi',
#   'Plot': "When Tony Stark and Bruce Banner try to jump-start a dormant peacekeeping program called Ultron, things go horribly wrong and it's up to Earth's mightiest heroes to stop the villainous Ultron from enacting his terrible plan.",
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.3/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '76%'},
#    {'Source': 'Metacritic', 'Value': '66/100'}],
#   'Runtime': '141 min',
#   'Writer': 'Joss Whedon, Stan Lee, Jack Kirby',
#   'Title': 'Avengers: Age of Ultron',
#   'imdbRating': '7.3',
#   'imdbVotes': '792,951'},
#  'tt4154756': {'Actors': 'Robert Downey Jr., Chris Hemsworth, Mark Ruffalo',
#   'Director': 'Anthony Russo, Joe Russo',
#   'Genre': 'Action, Adventure, Sci-Fi',
#   'Plot': 'The Avengers and their allies must be willing to sacrifice all in an attempt to defeat the powerful Thanos before his blitz of devastation and ruin puts an end to the universe.',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.4/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '85%'},
#    {'Source': 'Metacritic', 'Value': '68/100'}],
#   'Runtime': '149 min',
#   'Writer': 'Christopher Markus, Stephen McFeely, Stan Lee',
#   'Title': 'Avengers: Infinity War',
#   'imdbRating': '8.4',
#   'imdbVotes': '922,928'},
#  'tt0449088': {'Actors': 'Johnny Depp, Orlando Bloom, Keira Knightley',
#   'Director': 'Gore Verbinski',
#   'Genre': 'Action, Adventure, Fantasy',
#   'Plot': 'Captain Barbossa, Will Turner and Elizabeth Swann must sail off the edge of the map, navigate treachery and betrayal, find Jack Sparrow, and make their final alliances for one last decisive battle.',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.1/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '44%'},
#    {'Source': 'Metacritic', 'Value': '50/100'}],
#   'Runtime': '169 min',
#   'Writer': 'Ted Elliott, Terry Rossio, Stuart Beattie',
#   'Title': "Pirates of the Caribbean: At World's End",
#   'imdbRating': '7.1',
#   'imdbVotes': '615,274'},
#  'tt0974015': {'Actors': 'Ben Affleck, Gal Gadot, Jason Momoa',
#   'Director': 'Zack Snyder',
#   'Genre': 'Action, Adventure, Fantasy',
#   'Plot': "Fueled by his restored faith in humanity and inspired by Superman's selfless act, Bruce Wayne enlists the help of his new-found ally, Diana Prince, to face an even greater enemy.",
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.1/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '40%'},
#    {'Source': 'Metacritic', 'Value': '45/100'}],
#   'Runtime': '120 min',
#   'Writer': 'Jerry Siegel, Joe Shuster, Chris Terrio',
#   'Title': 'Justice League',
#   'imdbRating': '6.1',
#   'imdbVotes': '425,026'},
#  'tt2379713': {'Actors': 'Daniel Craig, Christoph Waltz, Léa Seydoux',
#   'Director': 'Sam Mendes',
#   'Genre': 'Action, Adventure, Thriller',
#   'Plot': "A cryptic message from James Bond's past sends him on a trail to uncover the existence of a sinister organisation named SPECTRE. With a new threat dawning, Bond learns the terrible truth about the author of all his pain in his most r",
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.8/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '63%'},
#    {'Source': 'Metacritic', 'Value': '60/100'}],
#   'Runtime': '148 min',
#   'Writer': 'John Logan, Neal Purvis, Robert Wade',
#   'Title': 'Spectre',
#   'imdbRating': '6.8',
#   'imdbVotes': '397,319'},
#  'tt11464830': {'Actors': 'J.J. Abrams, John Boyega, Madlyn Burkert, Anthony Carboni',
#   'Director': 'Steve Meyer',
#   'Genre': 'N/A',
#   'Plot': 'N/A',
#   'Rated': 'N/A',
#   'Ratings': [],
#   'Runtime': '126 min',
#   'Writer': 'N/A',
#   'Title': 'Live from the Red Carpet of Star Wars: The Rise of Skywalker',
#   'imdbRating': 'N/A',
#   'imdbVotes': 'N/A'},
#  'tt3778644': {'Actors': 'Alden Ehrenreich, Woody Harrelson, Emilia Clarke',
#   'Director': 'Ron Howard',
#   'Genre': 'Action, Adventure, Sci-Fi',
#   'Plot': "Board the Millennium Falcon and journey to a galaxy far, far away in an epic action-adventure that will set the course of one of the Star Wars saga's most unlikely heroes.",
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.9/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '70%'},
#    {'Source': 'Metacritic', 'Value': '62/100'}],
#   'Runtime': '135 min',
#   'Writer': 'Jonathan Kasdan, Lawrence Kasdan, George Lucas',
#   'Title': 'Solo: A Star Wars Story',
#   'imdbRating': '6.9',
#   'imdbVotes': '312,298'},
#  'tt0401729': {'Actors': 'Taylor Kitsch, Lynn Collins, Willem Dafoe',
#   'Director': 'Andrew Stanton',
#   'Genre': 'Action, Adventure, Sci-Fi',
#   'Plot': 'Transported to Barsoom, a Civil War vet discovers a barren planet seemingly inhabited by 12-foot tall barbarians. Finding himself prisoner of these creatures, he escapes, only to encounter Woola and a princess in desperate need of a ',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.6/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '52%'},
#    {'Source': 'Metacritic', 'Value': '51/100'}],
#   'Runtime': '132 min',
#   'Writer': 'Andrew Stanton, Mark Andrews, Michael Chabon',
#   'Title': 'John Carter',
#   'imdbRating': '6.6',
#   'imdbVotes': '262,518'},
#  'tt2975590': {'Actors': 'Ben Affleck, Henry Cavill, Amy Adams',
#   'Director': 'Zack Snyder',
#   'Genre': 'Action, Adventure, Sci-Fi',
#   'Plot': 'Fearing that the actions of Superman are left unchecked, Batman takes on the Man of Steel, while the world wrestles with what kind of a hero it really needs.',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.4/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '29%'},
#    {'Source': 'Metacritic', 'Value': '44/100'}],
#   'Runtime': '152 min',
#   'Writer': 'Chris Terrio, David S. Goyer, Bob Kane',
#   'Title': 'Batman v Superman: Dawn of Justice',
#   'imdbRating': '6.4',
#   'imdbVotes': '663,872'},
#  'tt6105098': {'Actors': 'Donald Glover, Beyoncé, Seth Rogen',
#   'Director': 'Jon Favreau',
#   'Genre': 'Animation, Adventure, Drama',
#   'Plot': 'After the murder of his father, a young lion prince flees his kingdom only to learn the true meaning of responsibility and bravery.',
#   'Rated': 'PG',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.8/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '52%'},
#    {'Source': 'Metacritic', 'Value': '55/100'}],
#   'Runtime': '118 min',
#   'Writer': 'Jeff Nathanson, Irene Mecchi, Jonathan Roberts',
#   'Title': 'The Lion King',
#   'imdbRating': '6.8',
#   'imdbVotes': '226,142'},
#  'tt0398286': {'Actors': 'Mandy Moore, Zachary Levi, Donna Murphy',
#   'Director': 'Nathan Greno, Byron Howard',
#   'Genre': 'Animation, Adventure, Comedy',
#   'Plot': 'The magically long-haired Rapunzel has spent her entire life in a tower, but now that a runaway thief has stumbled upon her, she is about to discover the world for the first time, and who she really is.',
#   'Rated': 'PG',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.7/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '89%'},
#    {'Source': 'Metacritic', 'Value': '71/100'}],
#   'Runtime': '100 min',
#   'Writer': 'Dan Fogelman, Jacob Grimm, Wilhelm Grimm',
#   'Title': 'Tangled',
#   'imdbRating': '7.7',
#   'imdbVotes': '422,812'},
#  'tt0413300': {'Actors': 'Tobey Maguire, Kirsten Dunst, Topher Grace',
#   'Director': 'Sam Raimi',
#   'Genre': 'Action, Adventure, Sci-Fi',
#   'Plot': 'A strange black entity from another world bonds with Peter Parker and causes inner turmoil as he contends with new villains, temptations, and revenge.',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.2/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '63%'},
#    {'Source': 'Metacritic', 'Value': '59/100'}],
#   'Runtime': '139 min',
#   'Writer': 'Sam Raimi, Ivan Raimi, Alvin Sargent',
#   'Title': 'Spider-Man 3',
#   'imdbRating': '6.2',
#   'imdbVotes': '523,552'},
#  'tt3498820': {'Actors': 'Chris Evans, Robert Downey Jr., Scarlett Johansson',
#   'Director': 'Anthony Russo, Joe Russo',
#   'Genre': 'Action, Adventure, Sci-Fi',
#   'Plot': "Political involvement in the Avengers' affairs causes a rift between Captain America and Iron Man.",
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.8/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '90%'},
#    {'Source': 'Metacritic', 'Value': '75/100'}],
#   'Runtime': '147 min',
#   'Writer': 'Christopher Markus, Stephen McFeely, Joe Simon',
#   'Title': 'Captain America: Civil War',
#   'imdbRating': '7.8',
#   'imdbVotes': '708,195'},
#  'tt0417741': {'Actors': 'Daniel Radcliffe, Emma Watson, Rupert Grint',
#   'Director': 'David Yates',
#   'Genre': 'Action, Adventure, Family',
#   'Plot': 'As Harry Potter begins his sixth year at Hogwarts, he discovers an old book marked as "the property of the Half-Blood Prince" and begins to learn more about Lord Voldemort\'s dark past.',
#   'Rated': 'PG',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.6/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '84%'},
#    {'Source': 'Metacritic', 'Value': '78/100'}],
#   'Runtime': '153 min',
#   'Writer': 'Steve Kloves, J.K. Rowling',
#   'Title': 'Harry Potter and the Half-Blood Prince',
#   'imdbRating': '7.6',
#   'imdbVotes': '499,516'},
#  'tt1170358': {'Actors': 'Ian McKellen, Martin Freeman, Richard Armitage',
#   'Director': 'Peter Jackson',
#   'Genre': 'Adventure, Fantasy',
#   'Plot': 'The dwarves, along with Bilbo Baggins and Gandalf the Grey, continue their quest to reclaim Erebor, their homeland, from Smaug. Bilbo Baggins is in possession of a mysterious and magical ring.',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.8/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '74%'},
#    {'Source': 'Metacritic', 'Value': '66/100'}],
#   'Runtime': '161 min',
#   'Writer': 'Fran Walsh, Philippa Boyens, Peter Jackson',
#   'Title': 'The Hobbit: The Desolation of Smaug',
#   'imdbRating': '7.8',
#   'imdbVotes': '622,714'},
#  'tt2310332': {'Actors': 'Ian McKellen, Martin Freeman, Richard Armitage',
#   'Director': 'Peter Jackson',
#   'Genre': 'Adventure, Fantasy',
#   'Plot': 'Bilbo and company are forced to engage in a war against an array of combatants and keep the Lonely Mountain from falling into the hands of a rising darkness.',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.4/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '59%'},
#    {'Source': 'Metacritic', 'Value': '59/100'}],
#   'Runtime': '144 min',
#   'Writer': 'Fran Walsh, Philippa Boyens, Peter Jackson',
#   'Title': 'The Hobbit: The Battle of the Five Armies',
#   'imdbRating': '7.4',
#   'imdbVotes': '493,713'},
#  'tt4630562': {'Actors': 'Vin Diesel, Jason Statham, Dwayne Johnson',
#   'Director': 'F. Gary Gray',
#   'Genre': 'Action, Adventure, Crime',
#   'Plot': 'When a mysterious woman seduces Dominic Toretto into the world of terrorism and a betrayal of those closest to him, the crew face trials that will test them as never before.',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.6/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '67%'},
#    {'Source': 'Metacritic', 'Value': '56/100'}],
#   'Runtime': '136 min',
#   'Writer': 'Gary Scott Thompson, Chris Morgan',
#   'Title': 'The Fate of the Furious',
#   'imdbRating': '6.6',
#   'imdbVotes': '219,020'},
#  'tt2382320': {'Actors': 'Daniel Craig, Ana de Armas, Rami Malek',
#   'Director': 'Cary Joji Fukunaga',
#   'Genre': 'Action, Adventure, Thriller',
#   'Plot': 'James Bond has left active service. His peace is short-lived when Felix Leiter, an old friend from the CIA, turns up asking for help, leading Bond onto the trail of a mysterious villain armed with dangerous new technology.',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.6/10'},
#    {'Source': 'Metacritic', 'Value': '70/100'}],
#   'Runtime': '163 min',
#   'Writer': 'Neal Purvis, Robert Wade, Cary Joji Fukunaga',
#   'Title': 'No Time to Die',
#   'imdbRating': '7.6',
#   'imdbVotes': '59,047'},
#  'tt0499549': {'Actors': 'Sam Worthington, Zoe Saldana, Sigourney Weaver',
#   'Director': 'James Cameron',
#   'Genre': 'Action, Adventure, Fantasy',
#   'Plot': 'A paraplegic Marine dispatched to the moon Pandora on a unique mission becomes torn between following his orders and protecting the world he feels is his home.',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.8/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '81%'},
#    {'Source': 'Metacritic', 'Value': '83/100'}],
#   'Runtime': '162 min',
#   'Writer': 'James Cameron',
#   'Title': 'Avatar',
#   'imdbRating': '7.8',
#   'imdbVotes': '1,155,483'},
#  'tt1345836': {'Actors': 'Christian Bale, Tom Hardy, Anne Hathaway',
#   'Director': 'Christopher Nolan',
#   'Genre': 'Action',
#   'Plot': "Eight years after the Joker's reign of anarchy, Batman, with the help of the enigmatic Catwoman, is forced from his exile to save Gotham City from the brutal guerrilla terrorist Bane.",
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.4/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '87%'},
#    {'Source': 'Metacritic', 'Value': '78/100'}],
#   'Runtime': '164 min',
#   'Writer': 'Jonathan Nolan, Christopher Nolan, David S. Goyer',
#   'Title': 'The Dark Knight Rises',
#   'imdbRating': '8.4',
#   'imdbVotes': '1,580,855'},
#  'tt1790809': {'Actors': 'Johnny Depp, Geoffrey Rush, Javier Bardem',
#   'Director': 'Joachim Rønning, Espen Sandberg',
#   'Genre': 'Action, Adventure, Fantasy',
#   'Plot': "Captain Jack Sparrow is pursued by old rival Captain Salazar and a crew of deadly ghosts who have escaped from the Devil's Triangle. They're determined to kill every pirate at sea...notably Jack.",
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.5/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '30%'},
#    {'Source': 'Metacritic', 'Value': '39/100'}],
#   'Runtime': '129 min',
#   'Writer': 'Jeff Nathanson, Terry Rossio, Ted Elliott',
#   'Title': 'Pirates of the Caribbean: Dead Men Tell No Tales',
#   'imdbRating': '6.5',
#   'imdbVotes': '280,529'},
#  'tt0830515': {'Actors': 'Daniel Craig, Olga Kurylenko, Mathieu Amalric',
#   'Director': 'Marc Forster',
#   'Genre': 'Action, Adventure, Thriller',
#   'Plot': "James Bond descends into mystery as he tries to stop a mysterious organisation from eliminating a country's most valuable resource.",
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.6/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '64%'},
#    {'Source': 'Metacritic', 'Value': '58/100'}],
#   'Runtime': '106 min',
#   'Writer': 'Paul Haggis, Neal Purvis, Robert Wade',
#   'Title': 'Quantum of Solace',
#   'imdbRating': '6.6',
#   'imdbVotes': '416,692'},
#  'tt0848228': {'Actors': 'Robert Downey Jr., Chris Evans, Scarlett Johansson',
#   'Director': 'Joss Whedon',
#   'Genre': 'Action, Adventure, Sci-Fi',
#   'Plot': "Earth's mightiest heroes must come together and learn to fight as a team if they are going to stop the mischievous Loki and his alien army from enslaving humanity.",
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.0/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '91%'},
#    {'Source': 'Metacritic', 'Value': '69/100'}],
#   'Runtime': '143 min',
#   'Writer': 'Joss Whedon, Zak Penn',
#   'Title': 'The Avengers',
#   'imdbRating': '8.0',
#   'imdbVotes': '1,307,340'},
#  'tt0770828': {'Actors': 'Henry Cavill, Amy Adams, Michael Shannon',
#   'Director': 'Zack Snyder',
#   'Genre': 'Action, Adventure, Sci-Fi',
#   'Plot': 'An alien child is evacuated from his dying world and sent to Earth to live among humans. His peace is threatened, when other survivors of his home planet invade Earth.',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.0/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '56%'},
#    {'Source': 'Metacritic', 'Value': '55/100'}],
#   'Runtime': '143 min',
#   'Writer': 'David S. Goyer, Christopher Nolan, Jerry Siegel',
#   'Title': 'Man of Steel',
#   'imdbRating': '7.0',
#   'imdbVotes': '729,757'},
#  'tt0499448': {'Actors': 'Ben Barnes, Skandar Keynes, Georgie Henley',
#   'Director': 'Andrew Adamson',
#   'Genre': 'Action, Adventure, Family',
#   'Plot': "The Pevensie siblings return to Narnia, where they are enlisted to once again help ward off an evil king and restore the rightful heir to the land's throne, Prince Caspian.",
#   'Rated': 'PG',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.5/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '66%'},
#    {'Source': 'Metacritic', 'Value': '62/100'}],
#   'Runtime': '150 min',
#   'Writer': 'Andrew Adamson, Christopher Markus, Stephen McFeely',
#   'Title': 'The Chronicles of Narnia: Prince Caspian',
#   'imdbRating': '6.5',
#   'imdbVotes': '201,653'},
#  'tt1210819': {'Actors': 'Johnny Depp, Armie Hammer, William Fichtner',
#   'Director': 'Gore Verbinski',
#   'Genre': 'Action, Adventure, Western',
#   'Plot': 'Native American warrior Tonto recounts the untold tales that transformed John Reid, a man of the law, into a legend of justice.',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.4/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '30%'},
#    {'Source': 'Metacritic', 'Value': '37/100'}],
#   'Runtime': '150 min',
#   'Writer': 'Justin Haythe, Ted Elliott, Terry Rossio',
#   'Title': 'The Lone Ranger',
#   'imdbRating': '6.4',
#   'imdbVotes': '227,500'},
#  'tt0948470': {'Actors': 'Andrew Garfield, Emma Stone, Rhys Ifans',
#   'Director': 'Marc Webb',
#   'Genre': 'Action, Adventure, Fantasy',
#   'Plot': 'After Peter Parker is bitten by a genetically altered spider, he gains newfound, spider-like powers and ventures out to save the city from the machinations of a mysterious reptilian foe.',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.9/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '72%'},
#    {'Source': 'Metacritic', 'Value': '66/100'}],
#   'Runtime': '136 min',
#   'Writer': 'James Vanderbilt, Alvin Sargent, Steve Kloves',
#   'Title': 'The Amazing Spider-Man',
#   'imdbRating': '6.9',
#   'imdbVotes': '580,643'},
#  'tt1440129': {'Actors': 'Alexander Skarsgård, Brooklyn Decker, Liam Neeson',
#   'Director': 'Peter Berg',
#   'Genre': 'Action, Adventure, Sci-Fi',
#   'Plot': 'A fleet of ships is forced to do battle with an armada of unknown origins in order to discover and thwart their destructive goals.',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.8/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '34%'},
#    {'Source': 'Metacritic', 'Value': '41/100'}],
#   'Runtime': '131 min',
#   'Writer': 'Jon Hoeber, Erich Hoeber',
#   'Title': 'Battleship',
#   'imdbRating': '5.8',
#   'imdbVotes': '241,758'},
#  'tt3371366': {'Actors': 'Mark Wahlberg, Anthony Hopkins, Josh Duhamel',
#   'Director': 'Michael Bay',
#   'Genre': 'Action, Adventure, Sci-Fi',
#   'Plot': "A deadly threat from Earth's history reappears and a hunt for a lost artifact takes place between Autobots and Decepticons, while Optimus Prime encounters his creator in space.",
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.2/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '15%'},
#    {'Source': 'Metacritic', 'Value': '27/100'}],
#   'Runtime': '154 min',
#   'Writer': 'Art Marcum, Matt Holloway, Ken Nolan',
#   'Title': 'Transformers: The Last Knight',
#   'imdbRating': '5.2',
#   'imdbVotes': '142,292'},
#  'tt0369610': {'Actors': 'Chris Pratt, Bryce Dallas Howard, Ty Simpkins',
#   'Director': 'Colin Trevorrow',
#   'Genre': 'Action, Adventure, Sci-Fi',
#   'Plot': 'A new theme park, built on the original site of Jurassic Park, creates a genetically modified hybrid dinosaur, the Indominus Rex, which escapes containment and goes on a killing spree.',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.0/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '71%'},
#    {'Source': 'Metacritic', 'Value': '59/100'}],
#   'Runtime': '124 min',
#   'Writer': 'Rick Jaffa, Amanda Silver, Colin Trevorrow',
#   'Title': 'Jurassic World',
#   'imdbRating': '7.0',
#   'imdbVotes': '600,686'},
#  'tt1409024': {'Actors': 'Will Smith, Tommy Lee Jones, Josh Brolin',
#   'Director': 'Barry Sonnenfeld',
#   'Genre': 'Action, Adventure, Comedy',
#   'Plot': "Agent J travels in time to M.I.B.'s early days in 1969 to stop an alien from assassinating his friend Agent K and changing history.",
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.8/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '68%'},
#    {'Source': 'Metacritic', 'Value': '58/100'}],
#   'Runtime': '106 min',
#   'Writer': 'Etan Cohen, Lowell Cunningham',
#   'Title': 'Men in Black 3',
#   'imdbRating': '6.8',
#   'imdbVotes': '345,853'},
#  'tt1055369': {'Actors': 'Shia LaBeouf, Megan Fox, Josh Duhamel',
#   'Director': 'Michael Bay',
#   'Genre': 'Action, Adventure, Sci-Fi',
#   'Plot': "Sam Witwicky leaves the Autobots behind for a normal life. But when his mind is filled with cryptic symbols, the Decepticons target him and he is dragged back into the Transformers' war.",
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.0/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '20%'},
#    {'Source': 'Metacritic', 'Value': '35/100'}],
#   'Runtime': '149 min',
#   'Writer': 'Ehren Kruger, Roberto Orci, Alex Kurtzman',
#   'Title': 'Transformers: Revenge of the Fallen',
#   'imdbRating': '6.0',
#   'imdbVotes': '394,072'},
#  'tt2109248': {'Actors': 'Mark Wahlberg, Nicola Peltz, Jack Reynor',
#   'Director': 'Michael Bay',
#   'Genre': 'Action, Adventure, Sci-Fi',
#   'Plot': 'When humanity allies with a bounty hunter in pursuit of Optimus Prime, the Autobots turn to a mechanic and his family for help.',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.6/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '17%'},
#    {'Source': 'Metacritic', 'Value': '32/100'}],
#   'Runtime': '165 min',
#   'Writer': 'Ehren Kruger',
#   'Title': 'Transformers: Age of Extinction',
#   'imdbRating': '5.6',
#   'imdbVotes': '304,674'},
#  'tt0955308': {'Actors': 'Russell Crowe, Cate Blanchett, Matthew Macfadyen',
#   'Director': 'Ridley Scott',
#   'Genre': 'Action, Adventure, Drama',
#   'Plot': 'In twelfth-century England, Robin Longstride and his band of marauders confront corruption in a local village and lead an uprising against the crown that will forever alter the balance of world power.',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.6/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '43%'},
#    {'Source': 'Metacritic', 'Value': '53/100'}],
#   'Runtime': '140 min',
#   'Writer': 'Brian Helgeland, Ethan Reiff, Cyrus Voris',
#   'Title': 'Robin Hood',
#   'imdbRating': '6.6',
#   'imdbVotes': '259,741'},
#  'tt0385752': {'Actors': 'Nicole Kidman, Daniel Craig, Dakota Blue Richards',
#   'Director': 'Chris Weitz',
#   'Genre': 'Adventure, Family, Fantasy',
#   'Plot': 'In a parallel universe, young Lyra Belacqua journeys to the far North to save her best friend and other kidnapped children from terrible experiments by a mysterious organization.',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.1/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '42%'},
#    {'Source': 'Metacritic', 'Value': '51/100'}],
#   'Runtime': '113 min',
#   'Writer': 'Chris Weitz, Philip Pullman',
#   'Title': 'The Golden Compass',
#   'imdbRating': '6.1',
#   'imdbVotes': '183,126'},
#  'tt6723592': {'Actors': 'John David Washington, Robert Pattinson, Elizabeth Debicki',
#   'Director': 'Christopher Nolan',
#   'Genre': 'Action, Sci-Fi, Thriller',
#   'Plot': 'Armed with only one word, Tenet, and fighting for the survival of the entire world, a Protagonist journeys through a twilight world of international espionage on a mission that will unfold in something beyond real time.',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.4/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '70%'},
#    {'Source': 'Metacritic', 'Value': '69/100'}],
#   'Runtime': '150 min',
#   'Writer': 'Christopher Nolan',
#   'Title': 'Tenet',
#   'imdbRating': '7.4',
#   'imdbVotes': '420,140'},
#  'tt1825683': {'Actors': "Chadwick Boseman, Michael B. Jordan, Lupita Nyong'o",
#   'Director': 'Ryan Coogler',
#   'Genre': 'Action, Adventure, Sci-Fi',
#   'Plot': "T'Challa, heir to the hidden but advanced kingdom of Wakanda, must step forward to lead his people into a new future and must confront a challenger from his country's past.",
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.3/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '96%'},
#    {'Source': 'Metacritic', 'Value': '88/100'}],
#   'Runtime': '134 min',
#   'Writer': 'Ryan Coogler, Joe Robert Cole, Stan Lee',
#   'Title': 'Black Panther',
#   'imdbRating': '7.3',
#   'imdbVotes': '675,764'},
#  'tt3606756': {'Actors': 'Craig T. Nelson, Holly Hunter, Sarah Vowell',
#   'Director': 'Brad Bird',
#   'Genre': 'Animation, Action, Adventure',
#   'Plot': 'The Incredibles family takes on a new mission which involves a change in family roles: Bob Parr (Mr. Incredible) must manage the house while his wife Helen (Elastigirl) goes out to save the world.',
#   'Rated': 'PG',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.6/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '93%'},
#    {'Source': 'Metacritic', 'Value': '80/100'}],
#   'Runtime': '118 min',
#   'Writer': 'Brad Bird',
#   'Title': 'Incredibles 2',
#   'imdbRating': '7.6',
#   'imdbVotes': '268,595'},
#  'tt6323140': {'Actors': 'Anthony Carboni, Andi Gutierrez, David W. Collins, Peter Townley',
#   'Director': 'N/A',
#   'Genre': 'Documentary, Sci-Fi',
#   'Plot': 'A behind the scenes look at Rogue One: A Star Wars Story.',
#   'Rated': 'N/A',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.5/10'}],
#   'Runtime': '89 min',
#   'Writer': 'Scott Bromley',
#   'Title': 'Rogue One: A Star Wars Story - World Premiere',
#   'imdbRating': '7.5',
#   'imdbVotes': '706'},
#  'tt2277860': {'Actors': "Ellen DeGeneres, Albert Brooks, Ed O'Neill",
#   'Director': 'Andrew Stanton, Angus MacLane',
#   'Genre': 'Animation, Adventure, Comedy',
#   'Plot': 'Friendly but forgetful blue tang Dory begins a search for her long-lost parents, and everyone learns a few things about the real meaning of family along the way.',
#   'Rated': 'PG',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.3/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '94%'},
#    {'Source': 'Metacritic', 'Value': '77/100'}],
#   'Runtime': '97 min',
#   'Writer': 'Andrew Stanton, Victoria Strouse',
#   'Title': 'Finding Dory',
#   'imdbRating': '7.3',
#   'imdbVotes': '254,441'},
#  'tt1979376': {'Actors': 'Tom Hanks, Tim Allen, Annie Potts',
#   'Director': 'Josh Cooley',
#   'Genre': 'Animation, Adventure, Comedy',
#   'Plot': 'When a new toy called "Forky" joins Woody and the gang, a road trip alongside old and new friends reveals how big the world can be for a toy.',
#   'Rated': 'G',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.7/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '97%'},
#    {'Source': 'Metacritic', 'Value': '84/100'}],
#   'Runtime': '100 min',
#   'Writer': 'John Lasseter, Andrew Stanton, Josh Cooley',
#   'Title': 'Toy Story 4',
#   'imdbRating': '7.7',
#   'imdbVotes': '222,521'},
#  'tt0435761': {'Actors': 'Tom Hanks, Tim Allen, Joan Cusack',
#   'Director': 'Lee Unkrich',
#   'Genre': 'Animation, Adventure, Comedy',
#   'Plot': "The toys are mistakenly delivered to a day-care center instead of the attic right before Andy leaves for college, and it's up to Woody to convince the other toys that they weren't abandoned and to return home.",
#   'Rated': 'G',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.2/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '98%'},
#    {'Source': 'Metacritic', 'Value': '92/100'}],
#   'Runtime': '103 min',
#   'Writer': 'John Lasseter, Andrew Stanton, Lee Unkrich',
#   'Title': 'Toy Story 3',
#   'imdbRating': '8.2',
#   'imdbVotes': '785,763'},
#  'tt3107386': {'Actors': 'Tomer Oz, Shaun Toub, Xueqi Wang',
#   'Director': 'Dan Mintz',
#   'Genre': 'Short, Action',
#   'Plot': 'N/A',
#   'Rated': 'N/A',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.4/10'}],
#   'Runtime': 'N/A',
#   'Writer': 'N/A',
#   'Title': 'Iron Man 3: The Prologue',
#   'imdbRating': '6.4',
#   'imdbVotes': '29'},
#  'tt3896198': {'Actors': 'Chris Pratt, Zoe Saldana, Dave Bautista',
#   'Director': 'James Gunn',
#   'Genre': 'Action, Adventure, Comedy',
#   'Plot': "The Guardians struggle to keep together as a team while dealing with their personal family issues, notably Star-Lord's encounter with his father the ambitious celestial being Ego.",
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.6/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '85%'},
#    {'Source': 'Metacritic', 'Value': '67/100'}],
#   'Runtime': '136 min',
#   'Writer': 'James Gunn, Dan Abnett, Andy Lanning',
#   'Title': 'Guardians of the Galaxy Vol. 2',
#   'imdbRating': '7.6',
#   'imdbVotes': '612,320'},
#  'tt1014759': {'Actors': 'Mia Wasikowska, Johnny Depp, Helena Bonham Carter',
#   'Director': 'Tim Burton',
#   'Genre': 'Adventure, Family, Fantasy',
#   'Plot': "Nineteen-year-old Alice returns to the magical world from her childhood adventure, where she reunites with her old friends and learns of her true destiny: to end the Red Queen's reign of terror.",
#   'Rated': 'PG',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.4/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '51%'},
#    {'Source': 'Metacritic', 'Value': '53/100'}],
#   'Runtime': '108 min',
#   'Writer': 'Linda Woolverton, Lewis Carroll',
#   'Title': 'Alice in Wonderland',
#   'imdbRating': '6.4',
#   'imdbVotes': '395,935'},
#  'tt1074638': {'Actors': 'Daniel Craig, Javier Bardem, Naomie Harris',
#   'Director': 'Sam Mendes',
#   'Genre': 'Action, Adventure, Thriller',
#   'Plot': "James Bond's loyalty to M is tested when her past comes back to haunt her. When MI6 comes under attack, 007 must track down and destroy the threat, no matter how personal the cost.",
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.7/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '92%'},
#    {'Source': 'Metacritic', 'Value': '81/100'}],
#   'Runtime': '143 min',
#   'Writer': 'Neal Purvis, Robert Wade, John Logan',
#   'Title': 'Skyfall',
#   'imdbRating': '7.7',
#   'imdbVotes': '648,536'},
#  'tt0903624': {'Actors': 'Martin Freeman, Ian McKellen, Richard Armitage',
#   'Director': 'Peter Jackson',
#   'Genre': 'Adventure, Fantasy',
#   'Plot': 'A reluctant Hobbit, Bilbo Baggins, sets out to the Lonely Mountain with a spirited group of dwarves to reclaim their mountain home, and the gold within it from the dragon Smaug.',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.8/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '64%'},
#    {'Source': 'Metacritic', 'Value': '58/100'}],
#   'Runtime': '169 min',
#   'Writer': 'Fran Walsh, Philippa Boyens, Peter Jackson',
#   'Title': 'The Hobbit: An Unexpected Journey',
#   'imdbRating': '7.8',
#   'imdbVotes': '780,103'},
#  'tt1453405': {'Actors': 'Billy Crystal, John Goodman, Steve Buscemi',
#   'Director': 'Dan Scanlon',
#   'Genre': 'Animation, Adventure, Comedy',
#   'Plot': 'A look at the relationship between Mike Wazowski (Billy Crystal) and James P. "Sully" Sullivan (John Goodman) during their days at Monsters University, when they weren\'t necessarily the best of friends.',
#   'Rated': 'G',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.2/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '80%'},
#    {'Source': 'Metacritic', 'Value': '65/100'}],
#   'Runtime': '104 min',
#   'Writer': 'Dan Scanlon, Daniel Gerson, Robert L. Baird',
#   'Title': 'Monsters University',
#   'imdbRating': '7.2',
#   'imdbVotes': '337,406'},
#  'tt1623205': {'Actors': 'James Franco, Michelle Williams, Rachel Weisz',
#   'Director': 'Sam Raimi',
#   'Genre': 'Adventure, Family, Fantasy',
#   'Plot': 'A small-time magician is swept away to an enchanted land and is forced into a power struggle between three witches.',
#   'Rated': 'PG',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.3/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '57%'},
#    {'Source': 'Metacritic', 'Value': '44/100'}],
#   'Runtime': '130 min',
#   'Writer': 'Mitchell Kapner, David Lindsay-Abaire, L. Frank Baum',
#   'Title': 'Oz the Great and Powerful',
#   'imdbRating': '6.3',
#   'imdbVotes': '202,782'},
#  'tt1877832': {'Actors': 'Patrick Stewart, Ian McKellen, Hugh Jackman',
#   'Director': 'Bryan Singer',
#   'Genre': 'Action, Adventure, Sci-Fi',
#   'Plot': 'The X-Men send Wolverine to the past in a desperate effort to change history and prevent an event that results in doom for both humans and mutants.',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.9/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '90%'},
#    {'Source': 'Metacritic', 'Value': '75/100'}],
#   'Runtime': '132 min',
#   'Writer': 'Simon Kinberg, Jane Goldman, Matthew Vaughn',
#   'Title': 'X-Men: Days of Future Past',
#   'imdbRating': '7.9',
#   'imdbVotes': '680,527'},
#  'tt1872181': {'Actors': 'Andrew Garfield, Emma Stone, Jamie Foxx',
#   'Director': 'Marc Webb',
#   'Genre': 'Action, Adventure, Fantasy',
#   'Plot': 'When New York is put under siege by Oscorp, it is up to Spider-Man to save the city he swore to protect as well as his loved ones.',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.6/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '52%'},
#    {'Source': 'Metacritic', 'Value': '53/100'}],
#   'Runtime': '142 min',
#   'Writer': 'Alex Kurtzman, Roberto Orci, Jeff Pinkner',
#   'Title': 'The Amazing Spider-Man 2',
#   'imdbRating': '6.6',
#   'imdbVotes': '435,019'},
#  'tt1216475': {'Actors': 'Owen Wilson, Larry the Cable Guy, Michael Caine',
#   'Director': 'John Lasseter, Bradford Lewis',
#   'Genre': 'Animation, Adventure, Comedy',
#   'Plot': 'Star race car Lightning McQueen and his pal Mater head overseas to compete in the World Grand Prix race. But the road to the championship becomes rocky as Mater gets caught up in an intriguing adventure of his own: international espi',
#   'Rated': 'G',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.1/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '40%'},
#    {'Source': 'Metacritic', 'Value': '57/100'}],
#   'Runtime': '106 min',
#   'Writer': 'John Lasseter, Bradford Lewis, Dan Fogelman',
#   'Title': 'Cars 2',
#   'imdbRating': '6.1',
#   'imdbVotes': '172,174'},
#  'tt3480822': {'Actors': 'Scarlett Johansson, Florence Pugh, David Harbour',
#   'Director': 'Cate Shortland',
#   'Genre': 'Action, Adventure, Sci-Fi',
#   'Plot': 'Natasha Romanoff confronts the darker parts of her ledger when a dangerous conspiracy with ties to her past arises.',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.8/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '79%'},
#    {'Source': 'Metacritic', 'Value': '67/100'}],
#   'Runtime': '134 min',
#   'Writer': 'Eric Pearson, Jac Schaeffer, Ned Benson',
#   'Title': 'Black Widow',
#   'imdbRating': '6.8',
#   'imdbVotes': '218,299'},
#  'tt11638654': {'Actors': 'Furkan Basaran, Burak Duran, Hasan Eltutan',
#   'Director': 'Furkan Basaran',
#   'Genre': 'Short, Crime',
#   'Plot': 'A crime story about two brothers that meets after years for a Feast of Ramadan.',
#   'Rated': 'N/A',
#   'Ratings': [],
#   'Runtime': 'N/A',
#   'Writer': 'Furkan Basaran, Sertac Bozkurt, Yasar Mutlu',
#   'Title': 'Fast',
#   'imdbRating': 'N/A',
#   'imdbVotes': 'N/A'},
#  'tt8647300': {'Actors': 'Luke Brown, Nick Murphy, Paul Ritchey, Josh Henderson',
#   'Director': 'Nick Murphy',
#   'Genre': 'Short, Action, Adventure, Comedy, Sci-Fi',
#   'Plot': 'An action-packed 3D adventure set in an analog world unlike anything captured on the internet. Sam Flynn (Luke Brown) is a cantankerous 27 year-old haunted by the mysterious disappearance ...',
#   'Rated': 'N/A',
#   'Ratings': [{'Source': 'Rotten Tomatoes', 'Value': '51%'}],
#   'Runtime': '3 min',
#   'Writer': 'Luke Brown, Nick Murphy',
#   'Title': 'TRON: Legacy - Low Rez',
#   'imdbRating': 'N/A',
#   'imdbVotes': 'N/A'},
#  'tt1190080': {'Actors': 'John Cusack, Thandiwe Newton, Chiwetel Ejiofor',
#   'Director': 'Roland Emmerich',
#   'Genre': 'Action, Adventure, Sci-Fi',
#   'Plot': 'A frustrated writer struggles to keep his family alive when a series of global catastrophes threatens to annihilate mankind.',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.8/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '39%'},
#    {'Source': 'Metacritic', 'Value': '49/100'}],
#   'Runtime': '158 min',
#   'Writer': 'Roland Emmerich, Harald Kloser',
#   'Title': '2012',
#   'imdbRating': '5.8',
#   'imdbVotes': '363,545'},
#  'tt4123430': {'Actors': 'Eddie Redmayne, Katherine Waterston, Dan Fogler',
#   'Director': 'David Yates',
#   'Genre': 'Adventure, Family, Fantasy',
#   'Plot': 'The second installment of the "Fantastic Beasts" series featuring the adventures of Magizoologist Newt Scamander.',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.5/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '36%'},
#    {'Source': 'Metacritic', 'Value': '52/100'}],
#   'Runtime': '134 min',
#   'Writer': 'J.K. Rowling',
#   'Title': 'Fantastic Beasts: The Crimes of Grindelwald',
#   'imdbRating': '6.5',
#   'imdbVotes': '238,313'},
#  'tt0438488': {'Actors': 'Christian Bale, Sam Worthington, Anton Yelchin',
#   'Director': 'McG',
#   'Genre': 'Action, Sci-Fi',
#   'Plot': 'In 2018, a mysterious new weapon in the war against the machines, half-human and half-machine, comes to John Connor on the eve of a resistance attack on Skynet. But whose side is he on, and can he be trusted?',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.5/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '33%'},
#    {'Source': 'Metacritic', 'Value': '49/100'}],
#   'Runtime': '115 min',
#   'Writer': 'John Brancato, Michael Ferris',
#   'Title': 'Terminator Salvation',
#   'imdbRating': '6.5',
#   'imdbVotes': '350,956'},
#  'tt1133985': {'Actors': 'Ryan Reynolds, Blake Lively, Peter Sarsgaard',
#   'Director': 'Martin Campbell',
#   'Genre': 'Action, Adventure, Sci-Fi',
#   'Plot': 'Reckless test pilot Hal Jordan is granted an alien ring that bestows him with otherworldly powers that inducts him into an intergalactic police force, the Green Lantern Corps.',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.5/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '26%'},
#    {'Source': 'Metacritic', 'Value': '39/100'}],
#   'Runtime': '114 min',
#   'Writer': 'Greg Berlanti, Michael Green, Marc Guggenheim',
#   'Title': 'Green Lantern',
#   'imdbRating': '5.5',
#   'imdbVotes': '275,254'},
#  'tt6565702': {'Actors': 'James McAvoy, Michael Fassbender, Jennifer Lawrence',
#   'Director': 'Simon Kinberg',
#   'Genre': 'Action, Adventure, Sci-Fi',
#   'Plot': 'Jean Grey begins to develop incredible powers that corrupt and turn her into a Dark Phoenix, causing the X-Men to decide if her life is worth more than all of humanity.',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.7/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '22%'},
#    {'Source': 'Metacritic', 'Value': '43/100'}],
#   'Runtime': '113 min',
#   'Writer': 'Simon Kinberg',
#   'Title': 'Dark Phoenix',
#   'imdbRating': '5.7',
#   'imdbVotes': '170,391'},
#  'tt7146812': {'Actors': 'Tom Holland, Chris Pratt, Julia Louis-Dreyfus',
#   'Director': 'Dan Scanlon',
#   'Genre': 'Animation, Adventure, Comedy',
#   'Plot': 'Two elven brothers embark on a quest to bring their father back for one day.',
#   'Rated': 'PG',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.4/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '88%'},
#    {'Source': 'Metacritic', 'Value': '61/100'}],
#   'Runtime': '102 min',
#   'Writer': 'Dan Scanlon, Keith Bunin, Jason Headley',
#   'Title': 'Onward',
#   'imdbRating': '7.4',
#   'imdbVotes': '125,488'},
#  'tt7126948': {'Actors': 'Gal Gadot, Chris Pine, Kristen Wiig',
#   'Director': 'Patty Jenkins',
#   'Genre': 'Action, Adventure, Fantasy',
#   'Plot': 'Diana must contend with a work colleague and businessman, whose desire for extreme wealth sends the world down a path of destruction, after an ancient artifact that grants wishes goes missing.',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.4/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '58%'},
#    {'Source': 'Metacritic', 'Value': '60/100'}],
#   'Runtime': '151 min',
#   'Writer': 'Patty Jenkins, Geoff Johns, Dave Callaham',
#   'Title': 'Wonder Woman 1984',
#   'imdbRating': '5.4',
#   'imdbVotes': '230,201'},
#  'tt1399103': {'Actors': 'Shia LaBeouf, Rosie Huntington-Whiteley, Tyrese Gibson',
#   'Director': 'Michael Bay',
#   'Genre': 'Action, Adventure, Sci-Fi',
#   'Plot': 'The Autobots learn of a Cybertronian spacecraft hidden on the moon, and race against the Decepticons to reach it and to learn its secrets.',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.2/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '35%'},
#    {'Source': 'Metacritic', 'Value': '42/100'}],
#   'Runtime': '154 min',
#   'Writer': 'Ehren Kruger',
#   'Title': 'Transformers: Dark of the Moon',
#   'imdbRating': '6.2',
#   'imdbVotes': '394,139'},
#  'tt2345759': {'Actors': 'Tom Cruise, Sofia Boutella, Annabelle Wallis',
#   'Director': 'Alex Kurtzman',
#   'Genre': 'Action, Adventure, Fantasy',
#   'Plot': 'An ancient Egyptian princess is awakened from her crypt beneath the desert, bringing with her malevolence grown over millennia, and terrors that defy human comprehension.',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.4/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '16%'},
#    {'Source': 'Metacritic', 'Value': '34/100'}],
#   'Runtime': '110 min',
#   'Writer': 'David Koepp, Christopher McQuarrie, Dylan Kussman',
#   'Title': 'The Mummy',
#   'imdbRating': '5.4',
#   'imdbVotes': '179,540'},
#  'tt1351685': {'Actors': 'Nicholas Hoult, Stanley Tucci, Ewan McGregor',
#   'Director': 'Bryan Singer',
#   'Genre': 'Animation, Adventure, Fantasy',
#   'Plot': 'The ancient war between humans and a race of giants is reignited when Jack, a young farmhand fighting for a kingdom and the love of a princess, opens a gateway between the two worlds.',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.2/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '52%'},
#    {'Source': 'Metacritic', 'Value': '51/100'}],
#   'Runtime': '114 min',
#   'Writer': 'Darren Lemke, Christopher McQuarrie, Dan Studney',
#   'Title': 'Jack the Giant Slayer',
#   'imdbRating': '6.2',
#   'imdbVotes': '134,871'},
#  'tt2820852': {'Actors': 'Vin Diesel, Paul Walker, Dwayne Johnson',
#   'Director': 'James Wan',
#   'Genre': 'Action, Adventure, Thriller',
#   'Plot': 'Deckard Shaw seeks revenge against Dominic Toretto and his family for his comatose brother.',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.1/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '82%'},
#    {'Source': 'Metacritic', 'Value': '67/100'}],
#   'Runtime': '137 min',
#   'Writer': 'Chris Morgan, Gary Scott Thompson',
#   'Title': 'Fast & Furious 7',
#   'imdbRating': '7.1',
#   'imdbVotes': '374,621'},
#  'tt1408101': {'Actors': 'Chris Pine, Zachary Quinto, Zoe Saldana',
#   'Director': 'J.J. Abrams',
#   'Genre': 'Action, Adventure, Sci-Fi',
#   'Plot': 'After the crew of the Enterprise find an unstoppable force of terror from within their own organization, Captain Kirk leads a manhunt to a war-zone world to capture a one-man weapon of mass destruction.',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.7/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '84%'},
#    {'Source': 'Metacritic', 'Value': '72/100'}],
#   'Runtime': '132 min',
#   'Writer': 'Roberto Orci, Alex Kurtzman, Damon Lindelof',
#   'Title': 'Star Trek Into Darkness',
#   'imdbRating': '7.7',
#   'imdbVotes': '472,090'},
#  'tt0816711': {'Actors': 'Brad Pitt, Mireille Enos, Daniella Kertesz',
#   'Director': 'Marc Forster',
#   'Genre': 'Action, Adventure, Horror',
#   'Plot': 'Former United Nations employee Gerry Lane traverses the world in a race against time to stop a zombie pandemic that is toppling armies and governments and threatens to destroy humanity itself.',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.0/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '66%'},
#    {'Source': 'Metacritic', 'Value': '63/100'}],
#   'Runtime': '116 min',
#   'Writer': 'Matthew Michael Carnahan, Drew Goddard, Damon Lindelof',
#   'Title': 'World War Z',
#   'imdbRating': '7.0',
#   'imdbVotes': '625,402'},
#  'tt1343092': {'Actors': 'Leonardo DiCaprio, Carey Mulligan, Joel Edgerton',
#   'Director': 'Baz Luhrmann',
#   'Genre': 'Drama, Romance',
#   'Plot': 'A writer and wall street trader, Nick, finds himself drawn to the past and lifestyle of his millionaire neighbor, Jay Gatsby.',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.2/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '48%'},
#    {'Source': 'Metacritic', 'Value': '55/100'}],
#   'Runtime': '143 min',
#   'Writer': 'Baz Luhrmann, Craig Pearce, F. Scott Fitzgerald',
#   'Title': 'The Great Gatsby',
#   'imdbRating': '7.2',
#   'imdbVotes': '502,642'},
#  'tt1663662': {'Actors': 'Idris Elba, Charlie Hunnam, Rinko Kikuchi',
#   'Director': 'Guillermo del Toro',
#   'Genre': 'Action, Adventure, Sci-Fi',
#   'Plot': 'As a war between humankind and monstrous sea creatures wages on, a former pilot and a trainee are paired up to drive a seemingly obsolete special weapon in a desperate effort to save the world from the apocalypse.',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.9/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '72%'},
#    {'Source': 'Metacritic', 'Value': '65/100'}],
#   'Runtime': '131 min',
#   'Writer': 'Travis Beacham, Guillermo del Toro',
#   'Title': 'Pacific Rim',
#   'imdbRating': '6.9',
#   'imdbVotes': '479,965'},
#  'tt1979388': {'Actors': 'Jeffrey Wright, Frances McDormand, Maleah Nipay-Padilla',
#   'Director': 'Peter Sohn',
#   'Genre': 'Animation, Adventure, Comedy',
#   'Plot': 'In a world where dinosaurs and humans live side-by-side, an Apatosaurus named Arlo makes an unlikely human friend.',
#   'Rated': 'PG',
# ...
#   'Director': 'Peter Lepeniotis',
#   'Genre': 'Animation, Adventure, Comedy',
#   'Plot': "An incorrigibly self-serving exiled squirrel finds himself helping his former park brethren survive by raiding a nut store, a location that also happens to be a front for a human gang's bank robbery.",
#   'Rated': 'PG',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.7/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '12%'},
#    {'Source': 'Metacritic', 'Value': '37/100'}],
#   'Runtime': '85 min',
#   'Writer': 'Peter Lepeniotis, Lorne Cameron, Daniel Woo',
#   'Title': 'The Nut Job',
#   'imdbRating': '5.7',
#   'imdbVotes': '27,603'},
#  'tt1535438': {'Actors': 'Meryl Streep, Tommy Lee Jones, Steve Carell',
#   'Director': 'David Frankel',
#   'Genre': 'Comedy, Drama, Romance',
#   'Plot': 'After thirty years of marriage, a middle-aged couple attends an intense, week-long counseling session to work on their relationship.',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.3/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '75%'},
#    {'Source': 'Metacritic', 'Value': '65/100'}],
#   'Runtime': '100 min',
#   'Writer': 'Vanessa Taylor',
#   'Title': 'Hope Springs',
#   'imdbRating': '6.3',
#   'imdbVotes': '41,908'},
#  'tt0800039': {'Actors': 'Kristen Bell, Jason Segel, Paul Rudd',
#   'Director': 'Nicholas Stoller',
#   'Genre': 'Comedy, Drama, Romance',
#   'Plot': "Devastated Peter takes a Hawaiian vacation in order to deal with the recent break-up with his TV star girlfriend, Sarah. Little does he know, Sarah's traveling to the same resort as her ex - and she's bringing along her new boyfriend",
#   'Rated': 'R',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.1/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '83%'},
#    {'Source': 'Metacritic', 'Value': '67/100'}],
#   'Runtime': '111 min',
#   'Writer': 'Jason Segel',
#   'Title': 'Forgetting Sarah Marshall',
#   'imdbRating': '7.1',
#   'imdbVotes': '273,831'},
#  'tt0871426': {'Actors': 'Tina Fey, Amy Poehler, Sigourney Weaver',
#   'Director': 'Michael McCullers',
#   'Genre': 'Comedy, Romance',
#   'Plot': 'A successful, single businesswoman who dreams of having a baby discovers she is infertile and hires a working class woman to be her unlikely surrogate.',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.0/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '63%'},
#    {'Source': 'Metacritic', 'Value': '55/100'}],
#   'Runtime': '99 min',
#   'Writer': 'Michael McCullers',
#   'Title': 'Baby Mama',
#   'imdbRating': '6.0',
#   'imdbVotes': '43,699'},
#  'tt0901476': {'Actors': 'Kate Hudson, Anne Hathaway, Candice Bergen',
#   'Director': 'Gary Winick',
#   'Genre': 'Comedy, Romance',
#   'Plot': 'Two best friends become rivals when they schedule their respective weddings on the same day.',
#   'Rated': 'PG',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.5/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '11%'},
#    {'Source': 'Metacritic', 'Value': '24/100'}],
#   'Runtime': '89 min',
#   'Writer': 'Greg DePaul, Casey Wilson, June Diane Raphael',
#   'Title': 'Bride Wars',
#   'imdbRating': '5.5',
#   'imdbVotes': '103,943'},
#  'tt1605783': {'Actors': 'Owen Wilson, Rachel McAdams, Kathy Bates',
#   'Director': 'Woody Allen',
#   'Genre': 'Comedy, Fantasy, Romance',
#   'Plot': "While on a trip to Paris with his fiancée's family, a nostalgic screenwriter finds himself mysteriously going back to the 1920s every day at midnight.",
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.7/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '93%'},
#    {'Source': 'Metacritic', 'Value': '81/100'}],
#   'Runtime': '94 min',
#   'Writer': 'Woody Allen',
#   'Title': 'Midnight in Paris',
#   'imdbRating': '7.7',
#   'imdbVotes': '403,520'},
#  'tt4555426': {'Actors': 'Gary Oldman, Lily James, Kristin Scott Thomas',
#   'Director': 'Joe Wright',
#   'Genre': 'Biography, Drama, History',
#   'Plot': 'In May 1940, the fate of World War II hangs on Winston Churchill, who must decide whether to negotiate with Adolf Hitler, or fight on knowing that it could mean the end of the British Empire.',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.4/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '84%'},
#    {'Source': 'Metacritic', 'Value': '75/100'}],
#   'Runtime': '125 min',
#   'Writer': 'Anthony McCarten',
#   'Title': 'Darkest Hour',
#   'imdbRating': '7.4',
#   'imdbVotes': '185,174'},
#  'tt0431308': {'Actors': 'Hilary Swank, Gerard Butler, Harry Connick Jr.',
#   'Director': 'Richard LaGravenese',
#   'Genre': 'Comedy, Drama, Romance',
#   'Plot': 'A young widow discovers that her late husband has left her 10 messages intended to help ease her pain and start a new life.',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.0/10'},
#    {'Source': 'Metacritic', 'Value': '39/100'}],
#   'Runtime': '126 min',
#   'Writer': 'Richard LaGravenese, Steven Rogers, Cecelia Ahern',
#   'Title': 'P.S. I Love You',
#   'imdbRating': '7.0',
#   'imdbVotes': '204,178'},
#  'tt5619332': {'Actors': 'Melissa McCarthy, Matt Walsh, Molly Gordon',
#   'Director': 'Ben Falcone',
#   'Genre': 'Comedy',
#   'Plot': 'After her husband abruptly asks for a divorce, a middle-aged mother returns to college in order to complete her degree.',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.6/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '38%'},
#    {'Source': 'Metacritic', 'Value': '46/100'}],
#   'Runtime': '105 min',
#   'Writer': 'Melissa McCarthy, Ben Falcone',
#   'Title': 'Life of the Party',
#   'imdbRating': '5.6',
#   'imdbVotes': '35,755'},
#  'tt0892318': {'Actors': 'Amanda Seyfried, Gael García Bernal, Vanessa Redgrave',
#   'Director': 'Gary Winick',
#   'Genre': 'Adventure, Comedy, Drama',
#   'Plot': 'Sophie dreams of becoming a writer and travels to Verona, Italy where she meets the "Secretaries of Juliet".',
#   'Rated': 'PG',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.5/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '42%'},
#    {'Source': 'Metacritic', 'Value': '50/100'}],
#   'Runtime': '105 min',
#   'Writer': 'Jose Rivera, Tim Sullivan',
#   'Title': 'Letters to Juliet',
#   'imdbRating': '6.5',
#   'imdbVotes': '96,298'},
#  'tt1798684': {'Actors': 'Jake Gyllenhaal, Rachel McAdams, Oona Laurence',
#   'Director': 'Antoine Fuqua',
#   'Genre': 'Action, Crime, Drama',
#   'Plot': 'After a fatal incident sends him on a rampant path of destruction, a champion boxer fights to get custody of his daughter and revive his professional career.',
#   'Rated': 'R',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.4/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '60%'},
#    {'Source': 'Metacritic', 'Value': '57/100'}],
#   'Runtime': '124 min',
#   'Writer': 'Kurt Sutter',
#   'Title': 'Southpaw',
#   'imdbRating': '7.4',
#   'imdbVotes': '225,894'},
#  'tt2406566': {'Actors': 'Charlize Theron, James McAvoy, John Goodman',
#   'Director': 'David Leitch',
#   'Genre': 'Action, Thriller',
#   'Plot': 'An undercover MI6 agent is sent to Berlin during the Cold War to investigate the murder of a fellow agent and recover a missing list of double agents.',
#   'Rated': 'R',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.7/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '79%'},
#    {'Source': 'Metacritic', 'Value': '63/100'}],
#   'Runtime': '115 min',
#   'Writer': 'Kurt Johnstad, Antony Johnston, Sam Hart',
#   'Title': 'Atomic Blonde',
#   'imdbRating': '6.7',
#   'imdbVotes': '184,340'},
#  'tt0783233': {'Actors': 'Keira Knightley, James McAvoy, Brenda Blethyn',
#   'Director': 'Joe Wright',
#   'Genre': 'Drama, Mystery, Romance',
#   'Plot': "Thirteen-year-old fledgling writer Briony Tallis irrevocably changes the course of several lives when she accuses her older sister's lover of a crime he did not commit.",
#   'Rated': 'R',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.8/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '83%'},
#    {'Source': 'Metacritic', 'Value': '85/100'}],
#   'Runtime': '123 min',
#   'Writer': 'Ian McEwan, Christopher Hampton',
#   'Title': 'Atonement',
#   'imdbRating': '7.8',
#   'imdbVotes': '262,601'},
#  'tt3397884': {'Actors': 'Emily Blunt, Josh Brolin, Benicio Del Toro',
#   'Director': 'Denis Villeneuve',
#   'Genre': 'Action, Crime, Drama',
#   'Plot': 'An idealistic FBI agent is enlisted by a government task force to aid in the escalating war against drugs at the border area between the U.S. and Mexico.',
#   'Rated': 'R',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.6/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '92%'},
#    {'Source': 'Metacritic', 'Value': '82/100'}],
#   'Runtime': '121 min',
#   'Writer': 'Taylor Sheridan',
#   'Title': 'Sicario',
#   'imdbRating': '7.6',
#   'imdbVotes': '395,840'},
#  'tt1259528': {'Actors': "Gerard Butler, Pablo Schreiber, O'Shea Jackson Jr.",
#   'Director': 'Christian Gudegast',
#   'Genre': 'Action, Crime, Drama',
#   'Plot': "An elite unit of the LA County Sheriff's Dept. and the state's most successful bank robbery crew clash as the outlaws plan a seemingly impossible heist on the Federal Reserve Bank.",
#   'Rated': 'R',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.0/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '42%'},
#    {'Source': 'Metacritic', 'Value': '49/100'}],
#   'Runtime': '140 min',
#   'Writer': 'Christian Gudegast, Paul T. Scheuring',
#   'Title': 'Den of Thieves',
#   'imdbRating': '7.0',
#   'imdbVotes': '100,967'},
#  'tt0383010': {'Actors': 'Sean Hayes, Chris Diamantopoulos, Will Sasso',
#   'Director': 'Bobby Farrelly, Peter Farrelly',
#   'Genre': 'Comedy, Family',
#   'Plot': 'While trying to save their childhood orphanage, Moe, Larry and Curly inadvertently stumble into a murder plot and wind up starring in a reality television show.',
#   'Rated': 'PG',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '5.1/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '51%'},
#    {'Source': 'Metacritic', 'Value': '56/100'}],
#   'Runtime': '92 min',
#   'Writer': 'Mike Cerrone, Bobby Farrelly, Peter Farrelly',
#   'Title': 'The Three Stooges',
#   'imdbRating': '5.1',
#   'imdbVotes': '30,893'},
#  'tt2911666': {'Actors': 'Keanu Reeves, Michael Nyqvist, Alfie Allen',
#   'Director': 'Chad Stahelski, David Leitch',
#   'Genre': 'Action, Crime, Thriller',
#   'Plot': 'An ex-hit-man comes out of retirement to track down the gangsters that killed his dog and took everything from him.',
#   'Rated': 'R',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.4/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '86%'},
#    {'Source': 'Metacritic', 'Value': '68/100'}],
#   'Runtime': '101 min',
#   'Writer': 'Derek Kolstad',
#   'Title': 'John Wick',
#   'imdbRating': '7.4',
#   'imdbVotes': '576,028'},
#  'tt1655441': {'Actors': 'Blake Lively, Michiel Huisman, Harrison Ford',
#   'Director': 'Lee Toland Krieger',
#   'Genre': 'Drama, Fantasy, Romance',
#   'Plot': 'A young woman, born at the turn of the 20th century, is rendered ageless after an accident. After many solitary years, she meets a man who complicates the eternal life she has settled into.',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.2/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '55%'},
#    {'Source': 'Metacritic', 'Value': '51/100'}],
#   'Runtime': '112 min',
#   'Writer': 'J. Mills Goodloe, Salvador Paskowitz',
#   'Title': 'The Age of Adaline',
#   'imdbRating': '7.2',
#   'imdbVotes': '163,539'},
#  'tt1193631': {'Actors': 'Sharni Vinson, Rick Malambri, Adam Sevani',
#   'Director': 'Jon M. Chu',
#   'Genre': 'Drama, Music, Romance',
#   'Plot': "A tight-knit group of New York City street dancers find themselves pitted against the world's best hip hop dancers in a high-stakes showdown.",
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.2/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '47%'},
#    {'Source': 'Metacritic', 'Value': '45/100'}],
#   'Runtime': '107 min',
#   'Writer': 'Amy Andelson, Emily Meyer, Duane Adler',
#   'Title': 'Step Up 3D',
#   'imdbRating': '6.2',
#   'imdbVotes': '57,002'},
#  'tt1127180': {'Actors': 'Alison Lohman, Justin Long, Ruth Livier',
#   'Director': 'Sam Raimi',
#   'Genre': 'Horror',
#   'Plot': 'A loan officer who evicts an old woman from her home finds herself the recipient of a supernatural curse. Desperate, she turns to a seer to try and save her soul, while evil forces work to push her to a breaking point.',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.5/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '92%'},
#    {'Source': 'Metacritic', 'Value': '83/100'}],
#   'Runtime': '99 min',
#   'Writer': 'Sam Raimi, Ivan Raimi',
#   'Title': 'Drag Me to Hell',
#   'imdbRating': '6.5',
#   'imdbVotes': '194,294'},
#  'tt7371706': {'Actors': 'David LeRoy Anderson, Drew Goddard, Heather Langenkamp',
#   'Director': 'Drew Goddard',
#   'Genre': 'Documentary, Short',
#   'Plot': 'A documentary that explores how the monsters were brought to life in The Cabin in the Woods.',
#   'Rated': 'N/A',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.8/10'}],
#   'Runtime': '12 min',
#   'Writer': 'N/A',
#   'Title': 'The Cabin In The Woods: An Army of Nightmares - Makeup & Animatronic Effects',
#   'imdbRating': '6.8',
#   'imdbVotes': '45'},
#  'tt0993842': {'Actors': 'Saoirse Ronan, Cate Blanchett, Eric Bana',
#   'Director': 'Joe Wright',
#   'Genre': 'Action, Adventure, Drama',
#   'Plot': 'A sixteen-year-old girl who was raised by her father to be the perfect assassin is dispatched on a mission across Europe, tracked by a ruthless intelligence agent and her operatives.',
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.8/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '71%'},
#    {'Source': 'Metacritic', 'Value': '65/100'}],
#   'Runtime': '111 min',
#   'Writer': 'Seth Lochhead, David Farr',
#   'Title': 'Hanna',
#   'imdbRating': '6.8',
#   'imdbVotes': '194,345'},
#  'tt0389722': {'Actors': 'Josh Hartnett, Melissa George, Danny Huston',
#   'Director': 'David Slade',
#   'Genre': 'Action, Horror, Thriller',
#   'Plot': 'After an Alaskan town is plunged into darkness for a month, it is attacked by a bloodthirsty gang of vampires.',
#   'Rated': 'R',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.6/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '51%'},
#    {'Source': 'Metacritic', 'Value': '53/100'}],
#   'Runtime': '113 min',
#   'Writer': 'Steve Niles, Stuart Beattie, Brian Nelson',
#   'Title': '30 Days of Night',
#   'imdbRating': '6.6',
#   'imdbVotes': '170,142'},
#  'tt1073498': {'Actors': 'Sean Maguire, Kevin Sorbo, Carmen Electra',
#   'Director': 'Jason Friedberg, Aaron Seltzer',
#   'Genre': 'Comedy, Fantasy',
#   'Plot': "A spoof of 300 (2006) and many other movies, TV series/shows/commercials, video games and celebrities. King Leonidas of Sparta and his army of 12 go to war against Xerxes of Persia to fight to the death for Sparta's freedom.",
#   'Rated': 'PG-13',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '2.8/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '2%'},
#    {'Source': 'Metacritic', 'Value': '9/100'}],
#   'Runtime': '87 min',
#   'Writer': 'Jason Friedberg, Aaron Seltzer',
#   'Title': 'Meet the Spartans',
#   'imdbRating': '2.8',
#   'imdbVotes': '105,977'},
#  'tt2404311': {'Actors': 'Robert De Niro, Michelle Pfeiffer, Dianna Agron',
#   'Director': 'Luc Besson',
#   'Genre': 'Comedy, Crime, Thriller',
#   'Plot': 'The Manzoni family, a notorious mafia clan, is relocated to Normandy, France under the Witness Protection Program, where fitting in soon becomes challenging, as their old habits die hard.',
#   'Rated': 'R',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.3/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '28%'},
#    {'Source': 'Metacritic', 'Value': '42/100'}],
#   'Runtime': '111 min',
#   'Writer': 'Luc Besson, Michael Caleo, Tonino Benacquista',
#   'Title': 'The Family',
#   'imdbRating': '6.3',
#   'imdbVotes': '113,935'},
#  ...}

# %%
financials_15_df.head(2)
# Out:
#    imdb_code                                        title  release_year  \
# 0  tt4154796                            Avengers: Endgame          2019
# 1  tt1298650  Pirates of the Caribbean: On Stranger Tides          2011
#
#   release_month release_day   budget_$  domestic_box_office_$  \
# 0           Apr          23  400000000              858373000
# 1           May          20  379000000              241071802
#
#    worldwide_box_office_$  profit_loss_$  return_pct  domestic_%
# 0              2797800564     2397800564  599.450141   30.680278
# 1              1045713802      666713802  175.913932   23.053325

# %% [markdown]
# ### The list of movies with failed calls is filtered to only include important movies -- stored in manual_list. Their imdb codes are found manually and stored in manual_imdb. They are zipped together and used to once again call the omdb api  and update the attributes dictionary (you can call omdb api either using title or imdb code) .  <br> The API call is therefore made differently, and the source variables that make up the URL come from a different data structure, so easier to use new functions rather than adapt the main function

# %%
manual_list = ['Star Wars Ep. VII: The Force Awakens', 
'Star Wars Ep. VIII: The Last Jedi', 
'Prince of Persia: Sands of Time', 
'Fast and Furious 6', 
'The Chronicles of Narnia: The Voyage of the Daw…', 
'Harry Potter and the Deathly Hallows: Part II', 
'Harry Potter and the Deathly Hallows: Part I', 
'Fantastic Four: Rise of the Silver Surfer', 
'The Hangover 3', 
'Ford v. Ferrari', 
'Dr. Seuss’ The Grinch', 
'Mamma Mia: Here We Go Again!', 
'The Angry Birds Movie', 
'Wall Street 2: Money Never Sleeps',
'Dr. Seuss’ The Lorax', 
'All Eyez on Me', 
'John Wick: Chapter Two', 
'Underworld 3: Rise of the Lycans', 
'Halloween 2',        
'Precious (Based on the Novel Push by Sapphire)']

manual_imdb = ['tt2488496', 'tt2527336', 'tt0473075', 'tt1905041', 'tt0980970', 'tt1201607', 'tt0926084', 'tt0486576', 'tt1951261', 'tt1950186', 'tt2709692', 'tt6911608', 'tt1985949', 'tt1027718', 'tt1482459', 'tt1666185', 'tt4425200', 'tt0834001', 'tt1311067', 'tt0929632']

zipped_codes = list(zip(manual_list, manual_imdb))

# %%
def update_on_success(financials_15_df, movie_data, pair, imdb_code):
    title = pair[0]
    financials_15_df.loc[financials_15_df['title'] == title, 'imdb_code'] = imdb_code
    keys = ['Actors', 'Director', 'Genre', 'Plot', 'Rated', 'Ratings', 'Runtime', 'Writer', 'Title', 'imdbRating', 'imdbVotes']
    omdb_attrs[imdb_code] = {x:movie_data[x] for x in keys}

def update_get_page(url):
    response=requests.get(url)
    movie_data = json.loads(response.content.decode('utf-8')) 
    return movie_data

def update_make_omdb_dict(financials_15_df, omdb_key):
    '''Similar to preceding main api call function, but called afterwards for those movies that failed due to ambiguous title
    using imdb code instead of title. Easier to use totally new functions due to the different way the url is constructed'''
    for pair in zipped_codes:
        imdb_code = pair[1]
        url = 'http://www.omdbapi.com/?i=' + imdb_code + '&apikey=' + omdb_key
        try:
            movie_data = update_get_page(url)
            update_on_success(financials_15_df, movie_data, pair, imdb_code) 
        except:
            update_dud_url.append(pair[0])

     # delete any rows in financials_15yr where there is no imdb_code

    financials_15_df = financials_15_df[financials_15_df.imdb_code != 'No_code']
    return financials_15_df

# %%
financials_15_df = update_make_omdb_dict(financials_15_df, omdb_key)

# %% [markdown]
# ### Turn the attributes dict into a dataframe

# %%
def rating_formatter():
    '''updates attributes dict returned in above functions by exploding the ratings list, so we have a column for each site'''
    for key in omdb_attrs:
        for k in omdb_attrs[key]['Ratings']:
            outlet_ratings = list(k.values())
            if outlet_ratings[0] == 'Rotten Tomatoes':
                omdb_attrs[key]['RottenRating'] = outlet_ratings[1][:-1]
            elif outlet_ratings[0] == 'Metacritic':
                omdb_attrs[key]['MetacriticRating'] = outlet_ratings[1][:-4]


def clean_values():
    '''formats the dictionary for conversion to df '''
    for mov in omdb_attrs:
        actor_list = omdb_attrs[mov]['Actors'].split(',')
        actor_list = [ac.strip() for ac in actor_list]
        omdb_attrs[mov]['Actor_List'] = actor_list
        
        genre_list = omdb_attrs[mov]['Genre'].split(',')
        genre_list = [ge.strip() for ge in genre_list]
        omdb_attrs[mov]['Genre_List'] = genre_list
        
        writer_list = omdb_attrs[mov]['Writer'].split(',')
        writer_list = [wr.strip() for wr in writer_list]
        omdb_attrs[mov]['Writer_List'] = writer_list
        
        director_list = omdb_attrs[mov]['Director'].split(',')
        director_list=[di.strip() for di in director_list]
        omdb_attrs[mov]['Director_List'] = director_list
        
        try:
            runtime = int(omdb_attrs[mov]['Runtime'].split(' ')[0])
            omdb_attrs[mov]['Run_Time'] = runtime
        
        except:
            omdb_attrs[mov]['Run_Time'] = 0
        
        try:
            imdb_votes = int(omdb_attrs[mov]['imdbVotes'].replace(',',''))
            omdb_attrs[mov]['imdb_votes'] = imdb_votes
        except:
            omdb_attrs[mov]['imdb_votes'] = '0'


def make_attributes_df():
    '''makes the dataframe of movie metadata from ommdb'''
    rating_formatter()
    clean_values()
    
    # make attributes linking dict 
    to_df_dict = {}
    att_keys = ['Genre_List', 'Actor_List', 'Director_List', 'Writer_List',
          'Rated', 'Run_Time','MetacriticRating', 'RottenRating', 'imdbRating',
          'imdb_votes']
    for m in omdb_attrs:
        to_df_dict[m] = {}
        
        for ks in att_keys:
            try:
                to_df_dict[m][ks] = omdb_attrs[m][ks]
            except:
                to_df_dict[m][ks] = np.nan 

     
    #make the actual attributes_df  
    attributes_df = pd.DataFrame(to_df_dict).transpose()
    attributes_df.reset_index(inplace=True)
    attributes_df = attributes_df.rename(columns = {'index':'imdb_code'})

    # make numeric values and make a mean ratings column
    attributes_df['imdbRating'] = attributes_df['imdbRating'].replace('N/A',np.NaN)
    attributes_df[['RottenRating', 'MetacriticRating', 'imdbRating', 'imdb_votes', 'Run_Time']] = attributes_df[['RottenRating', 'MetacriticRating', 'imdbRating', 'imdb_votes', 'Run_Time']].astype('float')

    attributes_df['imdbRating'] = attributes_df['imdbRating'].map(lambda x: 10*x)

    attributes_df['mean_rating'] =  (attributes_df['imdbRating'] +  attributes_df['RottenRating'] +  attributes_df['MetacriticRating'])/3
    
    return attributes_df

# %%
attributes_df = make_attributes_df()

# %% [markdown]
# ## Save the dataframes, attributes dictionary and scraped list

# %%
def save_files(financials_list, numbers_df, financials_15_df, omdb_attrs, attributes_df):
    '''Saves raw dataframes at the end of session in which they were created'''
    numbers_df.to_csv('data/numbers_df.csv', index=False)
    financials_15_df.to_csv('data/financials_15_df.csv', index=False)
    attributes_df.to_csv('data/attributes_df.csv', index=False)
    
    with open("data/financials_list.json", "w") as ffp:
        json.dump(financials_list, ffp)

    with open("data/omdb_attrs.json", "w") as ffo:
        json.dump(omdb_attrs, ffo)

# %%
save_files(financials_list, numbers_df, financials_15_df, omdb_attrs, attributes_df)

# %% [markdown]
# **DATAFRAMES** <br><br>
# **numbers_df** - all financial data from The Numbers website<br>
# **financials_15_df** - all financial data for numbers movies in last 15 years <br>
# **financials_hits_df** - same data but filtered out loss making movies, those only succesful outside english speaking world and those with no documented figures <br>
# **financials_flops_df** - same but filtered out profit making movies <br>
# <br>
